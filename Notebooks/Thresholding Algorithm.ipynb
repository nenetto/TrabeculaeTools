# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt
from mpl_toolkits.mplot3d import Axes3D
import SimpleITK as sitk
import os

image = r'J:\Projects\PaperUSCBCT\FigureImagesOverlap\ImageFiles\AbdominalNeedleCT.nii'
imageOut = r'J:\Projects\PaperUSCBCT\FigureImagesOverlap\ImageFiles\AbdominalNeedleCT_Gradient.nii'

image = sitk.ReadImage(image)
imGrad =  sitk.Gradient(image)
sitk.WriteImage(imGrad,imageOut)


help(sitk.WriteImage)
# Out:
# Help on function WriteImage in module SimpleITK.SimpleITK:
#
# WriteImage(*args)
#     WriteImage(Image image, std::string const & fileName, bool useCompression=False)
#     WriteImage(Image image, VectorString fileNames, bool inUseCompression=False)

# %%
WorkingDir = 'J:\Projects\JHUTrabeculae\Results\DevelopedAlgorithm'
OriginalsPath = os.path.join(WorkingDir,'OriginalImages')

# %%
img = sitk.ReadImage(os.path.join(OriginalsPath,'CBCT_4.60mm_RoI1.nii'))
img = sitk.Cast(img,sitk.sitkFloat32)
img = sitk.GetArrayFromImage(img)

#Select a slice
mySlice = 20
img = img[mySlice,:,:]

# Normalize the slice
img = (img - img.min()) / (img.max() - img.min())

ax = plt.imshow(img);
plt.colorbar();
